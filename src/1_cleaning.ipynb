# %% [markdown]
# # Weather

# %% [markdown]
# ## Limpieza

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/weather_classification_data.csv')

# Normalize headers to lowercase and remove spaces
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
# Check for data types
df.dtypes
# Out:
# temperature             float64
# humidity                  int64
# wind_speed              float64
# precipitation_(%)       float64
# cloud_cover              object
# atmospheric_pressure    float64
# uv_index                  int64
# season                   object
# visibility_(km)         float64
# location                 object
# weather_type             object
# dtype: object

# %%
# Show categorical columns
df.select_dtypes(include='object').T
# Out:
#                       0              1         2        3         4      \
# cloud_cover   partly cloudy  partly cloudy     clear    clear  overcast
# season               Winter         Spring    Spring   Spring    Winter
# location             inland         inland  mountain  coastal  mountain
# weather_type          Rainy         Cloudy     Sunny    Sunny     Rainy
#
#                  5         6              7         8        9      ...  \
# cloud_cover   overcast  overcast  partly cloudy  overcast    clear  ...
# season          Summer    Winter         Winter    Winter   Winter  ...
# location        inland    inland         inland  mountain  coastal  ...
# weather_type    Cloudy     Snowy          Snowy     Snowy    Sunny  ...
#
#                       13190   13191   13192     13193     13194     13195  \
# cloud_cover   partly cloudy   clear   clear  overcast  overcast  overcast
# season               Summer  Summer  Summer    Winter    Spring    Summer
# location           mountain  inland  inland    inland   coastal  mountain
# weather_type          Sunny   Sunny   Sunny     Snowy    Cloudy     Rainy
#
#                 13196     13197     13198     13199
# cloud_cover    cloudy  overcast  overcast  overcast
# season         Winter    Autumn    Winter    Autumn
# location      coastal   coastal    inland  mountain
# weather_type    Snowy    Cloudy     Snowy     Rainy
#
# [4 rows x 13200 columns]

# %%
# Show numerical columns
df.select_dtypes(include='number').T
# Out:
#                         0        1        2        3       4        5      \
# temperature             14.00    39.00    30.00    38.00   27.00    32.00
# humidity                73.00    96.00    64.00    83.00   74.00    55.00
# wind_speed               9.50     8.50     7.00     1.50   17.00     3.50
# precipitation_(%)       82.00    71.00    16.00    82.00   66.00    26.00
# atmospheric_pressure  1010.82  1011.43  1018.72  1026.25  990.67  1010.03
# uv_index                 2.00     7.00     5.00     7.00    1.00     2.00
# visibility_(km)          3.50    10.00     5.50     1.00    2.50     5.00
#
#                        6       7       8        9      ...    13190    13191  \
# temperature            -2.00    3.00    3.00    28.00  ...    30.00    27.00
# humidity               97.00   85.00   83.00    74.00  ...    24.00    48.00
# wind_speed              8.00    6.00    6.00     8.50  ...     3.50     6.50
# precipitation_(%)      86.00   96.00   66.00   107.00  ...    16.00    14.00
# atmospheric_pressure  990.87  984.46  999.44  1012.13  ...  1017.54  1029.37
# uv_index                1.00    1.00    0.00     8.00  ...    11.00     8.00
# visibility_(km)         4.00    3.50    1.00     7.50  ...     6.50     8.00
#
#                         13192   13193    13194    13195    13196    13197  \
# temperature             31.00   -5.00    29.00    10.00    -1.00    30.00
# humidity                24.00   65.00    62.00    74.00    76.00    77.00
# wind_speed               8.00   15.50    13.00    14.50     3.50     5.50
# precipitation_(%)        5.00   50.00    17.00    71.00    23.00    28.00
# atmospheric_pressure  1029.61  982.57  1002.81  1003.15  1067.23  1012.69
# uv_index                 8.00    1.00     2.00     1.00     1.00     3.00
# visibility_(km)          9.00    5.00     5.00     1.00     6.00     9.00
#
#                        13198    13199
# temperature             3.00    -5.00
# humidity               76.00    38.00
# wind_speed             10.00     0.00
# precipitation_(%)      94.00    92.00
# atmospheric_pressure  984.27  1015.37
# uv_index                0.00     5.00
# visibility_(km)         2.00    10.00
#
# [7 rows x 13200 columns]

# %%
# Check for missing values
df.isnull().sum()
# Out:
# temperature             0
# humidity                0
# wind_speed              0
# precipitation_(%)       0
# cloud_cover             0
# atmospheric_pressure    0
# uv_index                0
# season                  0
# visibility_(km)         0
# location                0
# weather_type            0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='all').T
# Out:
#                         count unique       top  freq         mean        std  \
# temperature           13200.0    NaN       NaN   NaN    19.127576  17.386327
# humidity              13200.0    NaN       NaN   NaN    68.710833  20.194248
# wind_speed            13200.0    NaN       NaN   NaN     9.832197   6.908704
# precipitation_(%)     13200.0    NaN       NaN   NaN    53.644394  31.946541
# cloud_cover             13200      4  overcast  6090          NaN        NaN
# atmospheric_pressure  13200.0    NaN       NaN   NaN  1005.827896  37.199589
# uv_index              13200.0    NaN       NaN   NaN     4.005758     3.8566
# season                  13200      4    Winter  5610          NaN        NaN
# visibility_(km)       13200.0    NaN       NaN   NaN     5.462917   3.371499
# location                13200      3    inland  4816          NaN        NaN
# weather_type            13200      4     Rainy  3300          NaN        NaN
#
#                          min    25%      50%        75%      max
# temperature            -25.0    4.0     21.0       31.0    109.0
# humidity                20.0   57.0     70.0       84.0    109.0
# wind_speed               0.0    5.0      9.0       13.5     48.5
# precipitation_(%)        0.0   19.0     58.0       82.0    109.0
# cloud_cover              NaN    NaN      NaN        NaN      NaN
# atmospheric_pressure  800.12  994.8  1007.65  1016.7725  1199.21
# uv_index                 0.0    1.0      3.0        7.0     14.0
# season                   NaN    NaN      NaN        NaN      NaN
# visibility_(km)          0.0    3.0      5.0        7.5     20.0
# location                 NaN    NaN      NaN        NaN      NaN
# weather_type             NaN    NaN      NaN        NaN      NaN

# %%
# Check for unique values
df.nunique()
# Out:
# temperature              126
# humidity                  90
# wind_speed                97
# precipitation_(%)        110
# cloud_cover                4
# atmospheric_pressure    5456
# uv_index                  15
# season                     4
# visibility_(km)           41
# location                   3
# weather_type               4
# dtype: int64

# %%
df['weather_type'].unique()
# Out:
# array(['Rainy', 'Cloudy', 'Sunny', 'Snowy'], dtype=object)

# %%
# Values counts percentage * 100 foreach non-numeric column
print(f"{df['cloud_cover'].value_counts(normalize=True) * 100}\n")
print(f"{df['season'].value_counts(normalize=True) * 100}\n")
print(f"{df['location'].value_counts(normalize=True) * 100}\n")
print(f"{df['weather_type'].value_counts(normalize=True) * 100}\n")
# Out:
# cloud_cover
# overcast         46.136364
# partly cloudy    34.545455
# clear            16.204545
# cloudy            3.113636
# Name: proportion, dtype: float64
#
# season
# Winter    42.500000
# Spring    19.681818
# Autumn    18.939394
# Summer    18.878788
# Name: proportion, dtype: float64
#
# location
# inland      36.484848
# mountain    36.462121
# coastal     27.053030
# Name: proportion, dtype: float64
#
# weather_type
# Rainy     25.0
# Cloudy    25.0
# Sunny     25.0
# Snowy     25.0
# Name: proportion, dtype: float64

# %%
# save the cleaned data
df.to_csv('../data/processed/weather_classification_data.csv', index=False)
